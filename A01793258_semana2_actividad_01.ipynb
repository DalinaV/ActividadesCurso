# %% [markdown]
# <a href="https://colab.research.google.com/github/DalinaV/ActividadesCurso/blob/https%2Fgithub.com%2FPosgradoMNA%2Factividades-de-aprendizaje-DalinaV.git/A01793258_semana2_actividad_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Maestría en Inteligencia Artificial Aplicada**
# ##**Curso: Procesamiento de Lenguaje Natural (NLP)**
# ###Tecnológico de Monterrey
# ###Prof Luis Eduardo Falcón Morales
#
# ## **Adtividad de la Semana 02**
# ###**Introducción al procesamiento de texto.**

# %% [markdown]
# En esta actividad deberás utilizar los datos del siguiente archivo que se encuentra en Canvas:
#
# MNA_NLP_semana_02_Actividad_datos.txt
#
# El archivo contiene comentarios en inglés sobre servicios de comida de la página de Yelp: https://www.yelp.com/ .
#
# Son mil comentarios y forman parte del conjunto de datos que se encuentra en el Machine Learning Repository de la UCI, llamado "Sentiment Labelled Sentences": https://archive.ics.uci.edu/ml/datasets/Sentiment+Labelled+Sentences#

# %% [markdown]
# #**Parte 1. Cargamos los datos.**

# %% [markdown]
# Cargar los datos del archivo indicado y obtener una lista de longitud de 1000 strings/comentarios.
#
# Por el momento solamente requerimos las bibliotecas de Numpy y re, para el manejo de los arreglos y de las expresiones regulares en Python.
#
# En particular, no necesitarás en esta actividad la biblioteca de Pandas.
#
# ###**NOTA: En esta actividad no debes importar nada más, con estas dos bibliotecas será *suficiente*.**

# %%
import numpy as np    # importamos Numpy para el manejo de los arreglos.
import re             # importamos re para el manejo de las expresiones regulares.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Ejecuta las siguientes instrucciones para cargar la información del achivo dado:

with open('/content/drive/MyDrive/MNA_NLP_semana_02_Actividad_datos.txt', # puedes actualizar la ruta a tu archivo, en dado caso.
          mode='r',     # abrimos el archivo en modo lectura.
          ) as f:
    docs = f.readlines()    # separamos cada comenta rio por líneas

f.close()  # ya que tenemos la información en la variable docs, cerramos el archivo

# %%
type(docs) == list   # Verifica que tu variable "docs" es una lista
# Out:
# True

# %%
len(docs)==1000  # verifica que la longitud de "docs" es de mil comentarios.
# Out:
# True

# %%
docs[0:10]     # observa algunos de los primeros comentarios
# Out:
# ['Wow... Loved this place.\n',
#  'Crust is not good.\n',
#  'Not tasty and the texture was just nasty.\n',
#  'Stopped by during the late May bank holiday off Rick Steve recommendation and loved it.\n',
#  'The selection on the menu was great and so were the prices.\n',
#  'Now I am getting angry and I want my damn pho.\n',
#  "Honeslty it didn't taste THAT fresh.)\n",
#  'The potatoes were like rubber and you could tell they had been made up ahead of time being kept under a warmer.\n',
#  'The fries were great too.\n',
#  'A great touch.\n']

# %% [markdown]
# #**Parte 2: sección de preguntas (regex).**

# %% [markdown]
# ##**Instrucciones:**
#
# ###**A continuación deberás contestar cada una de las preguntas que te piden usando expresiones regulares (regex).**
#
# ###**Por el momento no hay restricción en cuanto al número de líneas de código que agregues, pero trata de incluir las mínimas posibles.**

# %% [markdown]
# *   **Pregunta 1.**
#
# Busca y elimina todos los saltos de línea '\n' que se encuentran al final de cada comentario.
#
# Una vez finalizado, imprime los primeros 10 comentarios del resultado obtenido.

# %%
docs1=[]
for comentario in docs:
    if re.sub(r'\n', '', comentario):
      new_string = re.sub(r'\n', '', comentario)
      docs1.append(new_string)
#print(docs1)

# %%
docs1[0:10]
# Out:
# ['Wow... Loved this place.',
#  'Crust is not good.',
#  'Not tasty and the texture was just nasty.',
#  'Stopped by during the late May bank holiday off Rick Steve recommendation and loved it.',
#  'The selection on the menu was great and so were the prices.',
#  'Now I am getting angry and I want my damn pho.',
#  "Honeslty it didn't taste THAT fresh.)",
#  'The potatoes were like rubber and you could tell they had been made up ahead of time being kept under a warmer.',
#  'The fries were great too.',
#  'A great touch.',
#  'Service was very prompt.',
#  'Would not go back.',
#  'The cashier had no care what so ever on what I had to say it still ended up being wayyy overpriced.',
#  '"I tried the Cape Cod ravoli, chicken,with cranberry...mmmm!"',
#  'I was disgusted because I was pretty sure that was human hair.',
#  'I was shocked because no signs indicate cash only.',
#  'Highly recommended.',
#  'Waitress was a little slow in service.',
# ...

# %% [markdown]
# *   **Pregunta 2.**
#
# Busca e imprime todas las palabras que terminan con dos o más signos de admiración seguidos, por ejemplo "!!!".
#
# Debes imprimir tanto la palabra como la totalidad de signos de admiración que le siguen.
#
# Indica cuántos resultados obtuviste.

# %%
docs2=[]
for comentario in docs1:
    if re.findall('(!!!|!!|!!!!|!!!!!|!!!!!!|!!!!!!!|!!!!!!!!|!!!!!!!!!|!!!!!!!!!!|!!!!!!!!!!!|!!!!!!!!!!!!!!!!!!!)$',comentario):
       new_string = re.findall('(!!!|!!|!!!!|!!!!!|!!!!!!|!!!!!!!|!!!!!!!!|!!!!!!!!!|!!!!!!!!!!|!!!!!!!!!!!|!!!!!!!!!!!!!!!!!!!)$',comentario)
       print(new_string)
       docs2.append(new_string)

print(len(docs2))
# Out:
# ['!!!!!']
# ['!!!']
# ['!!!']
# ['!!!']
# ['!!']
# ['!!!!']
# ['!!']
# ['!!']
# ['!!!!!!']
# ['!!!']
# ['!!!']
# ['!!']
# ['!!!']
# ['!!!']
# ['!!!']
# ['!!']
# ['!!']
# ['!!!!!!!!']
# ['!!!!!!!!!!!']
# ['!!']
# ['!!!!!!!!!!!!!!!!!!!']
# ['!!']
# ['!!']
# 23

# %%
docs2=[]
for comentario in docs1:
    if re.findall('[\w._%+-]+!{2,1000}',comentario):
       new_string = re.findall('[\w._%+-]+!{2,1000}',comentario)
       print(new_string)
       docs2.append(new_string)

print(len(docs2))
# Out:
# ['Firehouse!!!!!']
# ['APPETIZERS!!!']
# ['amazing!!!']
# ['buffet!!!']
# ['good!!']
# ['it!!!!']
# ['DELICIOUS!!']
# ['amazing!!']
# ['shawarrrrrrma!!!!!!']
# ['yucky!!!']
# ['steak!!!!!']
# ['delicious!!!']
# ['far!!']
# ['biscuits!!!']
# ['dry!!']
# ['disappointing!!!']
# ['awesome!!']
# ['Up!!']
# ['FLY!!!!!!!!']
# ['here!!!']
# ['great!!!!!!!!!!!!!!']
# ['packed!!']
# ['otherwise!!']
# ['amazing!!!!!!!!!!!!!!!!!!!']
# ['style!!']
# ['disappointed!!']
# 26

# %%
print("Son", len(docs2), "palabras que coinciden con dos o mas signos de admiración")
# Out:
# Son 26 palabras que coinciden con dos o mas signos de admiración

# %% [markdown]
# *   **Pregunta 3.**
#
# Busca e imprime todas las palabras que están escritas totalmente en mayúsculas. Cada coincidencia debe ser una sola palabra.
#
# Indica cuántas palabras encontraste.

# %%
docs3=[]
for comentario in docs1:
    if re.findall('([\w._%+-]+[A-Z]{2,10}|[A-Z]\+[A-Z]{1,20})',comentario):
       new_string= re.findall('([\w._%+-]+[A-Z]{2,10}|[A-Z]\+[A-Z]{1,20})',comentario)
       print(new_string)
       docs3.append(new_string)
     
print(len(docs3))
# Out:
# ['THAT']
# ['APPETIZERS']
# ['WILL', 'NEVER', 'EVER', 'STEP', 'FORWARD', 'AGAIN']
# ['LOVED']
# ['AND']
# ['REAL']
# ['BITCHES']
# ['NYC']
# ['STALE']
# ['DELICIOUS']
# ['WORST', 'EXPERIENCE', 'EVER']
# ['ALL']
# ['BARGAIN']
# ['NONE']
# ['FREEZING']
# ['AYCE']
# ['FLAVOR']
# ['NEVER']
# ['BBQ']
# ['UNREAL']
# ['OMG']
# ['BETTER']
# ['BLAND']
# ['RUDE', 'INCONSIDERATE', 'MANAGEMENT']
# ['WILL', 'NEVER', 'EVER', 'BACK', 'AND', 'HAVE', 'TOLD', 'MANY', 'PEOPLE', 'WHAT', 'HAD', 'HAPPENED']
# ['TOTAL', 'WASTE', 'TIME']
# ['LOVED']
# ['CONCLUSION']
# ['BEST']
# ['NOW']
# ['AVOID', 'THIS', 'ESTABLISHMENT']
# ['HOUR']
# ['NASTY']
# ['OMG']
# ['BEST']
# ['....THE', 'OWNERS', 'REALLY', 'REALLY']
# ['PERFECT']
# ['SCREAMS', 'LEGIT']
# ['MGM']
# ['BEST']
# ['FLY', 'FLY']
# ['FANTASTIC']
# ['GREAT']
# ['WAY']
# ['MUST', 'HAVE']
# ['OVERPRICED']
# ['BARE', 'HANDS']
# ['WEAK']
# ['SHOULD']
# ['WAAAAAA']
# ['VERY']
# ['NOT']
# 52

# %%
docs3=[]
for comentario in docs1:
    if re.findall('([\w._%+-][A-Z]{2,30})',comentario):
        new_string= re.findall('([\w._%+-][A-Z]{2,30})',comentario)
       

        if len(new_string)>1:
          for i in range(0,len(new_string)):
             #print(new_string[i], len(new_string[i]))
             docs3.append(new_string[i])
        else:
             docs3.append(new_string)

#print(len(docs3))
docs3
# Out:
# [['THAT'],
#  ['APPETIZERS'],
#  'WILL',
#  'NEVER',
#  'EVER',
#  'STEP',
#  'FORWARD',
#  'AGAIN',
#  ['LOVED'],
#  ['AND'],
#  ['REAL'],
#  ['BITCHES'],
#  ['NYC'],
#  ['STALE'],
#  ['DELICIOUS'],
#  'WORST',
#  'EXPERIENCE',
#  'EVER',
#  ['ALL'],
#  ['BARGAIN'],
#  ['NONE'],
#  ['FREEZING'],
#  ['AYCE'],
#  ['FLAVOR'],
#  ['NEVER'],
#  ['BBQ'],
#  ['UNREAL'],
#  ['OMG'],
#  ['BETTER'],
#  ['BLAND'],
#  'RUDE',
#  'INCONSIDERATE',
#  'MANAGEMENT',
#  'WILL',
#  'NEVER',
#  'EVER',
#  'BACK',
#  'AND',
#  'HAVE',
#  'TOLD',
#  'MANY',
#  'PEOPLE',
#  'WHAT',
#  'HAD',
#  'HAPPENED',
#  'TOTAL',
#  'WASTE',
#  'TIME',
#  ['LOVED'],
#  ['CONCLUSION'],
#  ['BEST'],
#  ['NOW'],
#  'AVOID',
#  'THIS',
#  'ESTABLISHMENT',
#  ['HOUR'],
#  ['NASTY'],
#  ['OMG'],
#  ['BEST'],
#  '.THE',
#  'OWNERS',
#  'REALLY',
#  'REALLY',
#  ['PERFECT'],
#  'SCREAMS',
#  'LEGIT',
#  ['MGM'],
#  ['BEST'],
#  'FLY',
#  'FLY',
#  ['FANTASTIC'],
#  ['GREAT'],
#  ['WAY'],
#  'MUST',
#  'HAVE',
# ...

# %%
print("Son", len(docs3), "palabras que estan en mayusculas")
# Out:
# Son 83 palabras que estan en mayusculas

# %% [markdown]
# *   **Pregunta 4.**
#
# Busca e imprime los comentarios en donde todos los caracteres alfabéticos (letras) están en mayúsculas.
#
# Cada coincidencia encontrada debe ser todo el comentario/enunciado.
#
# Indica cuántos resultados obtuviste.

# %%
docs4=[]
for comentario in docs1:
    if re.findall('(\w.*[\w._%+-][A-Z]{1,300})',comentario):
       new_string= re.findall('(\w.*[\w._%+-][A-Z]{1,300})',comentario)
       print(new_string)
       docs4.append(new_string)
     
print(len(docs4))
# Out:
# ["Honeslty it didn't taste THAT"]
# ['This place receives stars for their APPETIZERS']
# ['Never been to Hard Rock Casino before, WILL NEVER EVER STEP FORWARD IN IT AGAIN']
# ['I LOVED']
# ['The food was delicious, our bartender was attentive and personable AND']
# ['REAL']
# ['Host staff were, for lack of a better word, BITCHES']
# ['Delicious NYC']
# ['Unfortunately, we must have hit the bakery on leftover day because everything we ordered was STALE']
# ['DELICIOUS']
# ['The WORST EXPERIENCE EVER']
# ['Lobster Bisque, Bussell Sprouts, Risotto, Filet ALL']
# ['This is an unbelievable BARGAIN']
# ['Great place to have a couple drinks and watch any and all sporting events as the walls are covered with TV']
# ['The descriptions said ""yum yum sauce"" and another said ""eel sauce"", yet another said ""spicy mayo""...well NONE']
# ["It wasn't busy either) Also, the building was FREEZING"]
# ['Much better than the other AYCE']
# ...

# %%
print("Son", len(docs4), "los comentarios que tienen palabras que estan en mayusculas")
# Out:
# Son 61 los comentarios que tienen palabras que estan en mayusculas

# %% [markdown]
# *   **Pregunta 5.**
#
# Busca e imprime todas las palabras que tengan una vocal acentuada, del tipo á, é, í, ó, ú.
#
# Indica cuántos resultados obtuviste.

# %%
docs5=[]
for comentario in docs1:
    if re.findall('(\w*[a-zA-Z][À-ÿ])',comentario):
        new_string= re.findall('(\w*[a-zA-Z][À-ÿ])',comentario)
        print(new_string)
       
        docs5.append(new_string)
# Out:
# ['fiancé']
# ['Café']
# ['crê']
# ['puré']

# %%
print("Son", len(docs5), "las palabras que tienen una vocal acentuada")
# Out:
# Son 4 las palabras que tienen una vocal acentuada

# %% [markdown]
# *   **Pregunta 6.**
#
# Busca e imprime todas las cantidades numéricas monetarias, enteras o con decimales, que inician con el símbolo $\$$.
#
# Indica cuántos resultados obtuviste.

# %%
docs6=[]
for comentario in docs1:
    if re.findall('(\$[0-9,]+(.[0-9]{2})?)',comentario):
        new_string= re.findall('(\$[0-9,]+(.[0-9]{2})?)',comentario)
        print(new_string)
       
        docs6.append(new_string)

print(len(docs6))
# Out:
# [('$20,', '')]
# [('$4.00', '.00')]
# [('$17', '')]
# [('$3', '')]
# [('$35', '')]
# [('$7.85', '.85')]
# [('$12,', '')]
# [('$11.99', '.99')]
# 8

# %%
print("Son", len(docs6), "las cantidades monetarias enteras o con decimales")
# Out:
# Son 8 las cantidades monetarias enteras o con decimales

# %% [markdown]
# *   **Pregunta 7.**
#
# Busca e imprime todas las palabras que sean variantes de la palabra "love", sin importar si incluyen mayúsculas o minúsculas, o la manera en que esté conjugada o alguna otra variación que se haga con dicha palabra.
#
# Indica cuántos resultados obtuviste.

# %%
docs7=[]
for comentario in docs1:
    if re.findall('(?i)\W(love|lovee|LOVESS|LOVER|loved)',comentario):
        new_string= re.findall('(?i)\W(love|lovee|LOVESS|LOVER|loved)',comentario)
        print(new_string)
       
        docs7.append(new_string)

print(len(docs7))
# Out:
# ['Love']
# ['love']
# ['Love']
# ['love']
# ['love']
# ['LOVE']
# ['love']
# ['love']
# ['love']
# ['Love']
# ['love']
# ['love']
# ['love']
# ['love']
# ['love']
# ['love']
# ['love']
# ['love']
# ['Love']
# ['LOVE']
# ['love']
# ['love']
# ['love']
# ['love']
# ['love']
# ['love']
# ['love']
# ['love']
# ['love']
# ['love']
# ['love']
# ['love']
# ['love']
# ['love']
# ['love']
# 35

# %%
print("Son", len(docs7), "las veces que sale la palabra love o Love")
# Out:
# Son 35 las veces que sale la palabra love o Love

# %% [markdown]
# *   **Pregunta 8.**
#
# Busca e imprime todas las palabras, variantes de "so" y "good", que tengan dos o más "o" en "so" y 3 o más "o" en good.
#
# Indica cuántas encontraste.

# %%
docs8=[]
for comentario in docs1:
    if re.findall('(?i)\W(soo|sooo|goood|gooooood)',comentario):
        new_string= re.findall('(?i)\W(soo|sooo|goood|gooooood)',comentario)
        print(new_string)
       
        docs8.append(new_string)

print(len(docs8))
# Out:
# ['soo']
# ['soo']
# ['soo']
# ['soo']
# ['goood']
# ['soo']
# ['soo']
# ['soo']
# ['soo']
# ['soo']
# ['soo']
# ['soo']
# ['soo']
# 13

# %%
docs8=[]
for comentario in docs1:
    if re.findall('(?i)\W(soo|goood|sooo)|(^so+\w*?\b)|(go+\w*?d$)',comentario):
        new_string= re.findall('(?i)\W(soo|goood|sooo)|(^so+\w*?\b)|(go+\w*?d$)',comentario)
        print(new_string)
       
        docs8.append(new_string)

print(len(docs8))
# Out:
# [('soo', '', '')]
# [('soo', '', '')]
# [('soo', '', '')]
# [('soo', '', '')]
# [('goood', '', '')]
# [('soo', '', '')]
# [('soo', '', '')]
# [('soo', '', '')]
# [('soo', '', '')]
# [('soo', '', '')]
# [('soo', '', '')]
# [('soo', '', '')]
# [('soo', '', '')]
# 13

# %%
print("Son", len(docs8), "las veces que sale la palabra so good")
# Out:
# Son 13 las veces que sale la palabra so good

# %% [markdown]
# *   **Pregunta 9.**
#
# Busca e imprime todas las palabras que tengan una longitud mayor estrictamente a 10 caracteres alfabéticos.
#
# No se consideran los signos de puntuación o caracteres especiales en la longitud de estas cadenas, solo caracteres alfabéticos en mayúsculas o minúsculas.
#
# Indica la cantidad de palabras encontradas.

# %%
docs9=[]
for comentario in docs1:
    if re.findall('[a-zA-z0-9]{10,}',comentario):
        new_string= re.findall('[a-zA-z0-9]{10,}',comentario)
       
        if len(new_string)>1:
          for i in range(0,len(new_string)):
             #print(new_string[i], len(new_string[i]))
             docs9.append(new_string[i])
        else:
             docs9.append(new_string)

#print(len(docs3))
docs9
# Out:
# [['recommendation'],
#  ['overpriced'],
#  ['recommended'],
#  'restaurant',
#  'overwhelmed',
#  'restaurant',
#  'inexpensive',
#  ['establishment'],
#  ['refreshing'],
#  ['sunglasses'],
#  ['imaginative'],
#  'absolutely',
#  'restaurant',
#  ['APPETIZERS'],
#  ['definitely'],
#  ['apparently'],
#  ['opportunity'],
#  'experiencing',
#  'underwhelming',
#  'relationship',
#  ['unsatisfying'],
#  ['Everything'],
#  'disappointing',
#  'experience',
#  ['outrageously'],
#  ['Tigerlilly'],
#  ['personable'],
#  'restaurant',
#  'definitely',
#  ['atmosphere'],
#  'experience',
#  'disappointing',
#  ['Phenomenal'],
#  ['Definitely'],
#  ['overpriced'],
#  ['management'],
#  ['selections'],
#  ['expectations'],
#  ['restaurants'],
#  ['suggestions'],
#  ['disappointed'],
#  ['considering'],
#  ['restaurant'],
#  ['highlights'],
#  'Unfortunately',
#  'everything',
#  ['immediately'],
#  ['reasonably'],
#  ['Restaurant'],
#  ['ingredients'],
#  ['waitresses'],
#  'Everything',
# ...

# %%
print("Son", len(docs9), "las palabras con mas 10 caracteres alfabéticos")
# Out:
# Son 359 las palabras con mas 10 caracteres alfabéticos

# %% [markdown]
# *   **Pregunta 10.**
#
# Busca e imprime todas las palabras que inician con una letra mayúscula y terminan con una minúscula, pero que además no sea la primera palabra del comentario/string.
#
# Indica la cantidad de resultados obtenidos.

# %%
docs10=[]
for comentario in docs1:
    if re.findall(' [/^[A-Z]+[a-zA-Z]+[a-z]',comentario):
        new_string= re.findall(' [/^[A-Z]+[a-zA-Z]+[a-z]',comentario)
       
        if len(new_string)>1:
          for i in range(0,len(new_string)):
             #print(new_string[i], len(new_string[i]))
             docs10.append(new_string[i])
        else:
             docs10.append(new_string)

#print(len(docs3))
docs10
# Out:
# [[' Loved'],
#  ' May',
#  ' Rick',
#  ' Steve',
#  ' Cape',
#  ' Cod',
#  [' Vegas'],
#  ' Burrittos',
#  ' Blah',
#  [' The'],
#  [' They'],
#  [' Mexican'],
#  ' Luke',
#  ' Our',
#  [' Hiro'],
#  [' Firehouse'],
#  ' Greek',
#  ' Greek',
#  ' Heart',
#  ' Attack',
#  ' Grill',
#  ' Vegas',
#  ' Dos',
#  ' Gringos',
#  [' Jeff'],
#  [' Really'],
#  [' Excalibur'],
#  ' Very',
#  ' Bad',
#  ' Customer',
#  ' Service',
#  ' Vegas',
#  ' Rice',
#  ' Company',
#  [' Pho'],
#  ' Hard',
#  ' Rock',
#  ' Casino',
#  [' Buffet'],
#  [' Tigerlilly'],
#  [' Yama'],
#  [' Thai'],
#  [' Indian'],
#  [' Not'],
#  [' Vegas'],
#  [' Lox'],
#  ' Subway',
#  ' Subway',
#  [' Vegas'],
#  [' Vegas'],
#  ' Mandalay',
#  ' Bay',
#  [' Great'],
#  [' Voodoo'],
#  [' Phoenix'],
#  [' Vegas'],
#  ' Khao',
#  ' Soi',
#  [' Lemon'],
#  ' Joey',
#  ' Valley',
#  ' Phoenix',
#  ' Magazine',
#  [' Pho'],
#  [' Fridays'],
#  [' Tasty'],
#  [' Jamaican'],
#  ' Bisque',
#  ' Bussell',
#  ' Sprouts',
# ...

# %%
print("Son", len(docs10), "las palabras que empiezan con mayuscula y terminan en minuscula y no es la primera de cada comentario")

# %% [markdown]
# *   **Pregunta 11.**
#
# Busca e imprime la secuencia de dos o más palabras que están separadas por un guion, "-", sin que tengan espacios en blanco entre ellas.
#
# Por ejemplo "Go-Kart" sería válido, pero "Go  -Kart" o "Go  -  Kart" no lo serían.
#
# Indica la cantidad de resultados obtenidos.

# %%
docs11=[]
for comentario in docs1:
    if re.findall('^[a-zA-Z0-9]+(?:-[a-zA-Z0-9]+)*$',comentario):
       new_string = re.findall('^[a-zA-Z0-9]+(?:-[a-zA-Z0-9]+)*$',comentario)
       print(new_string)
       docs11.append(new_string)

print(len(docs11))
# Out:
# 0

# %%
print("Son", len(docs11), "las palabras separadas por guion")
# Out:
# Son 0 las palabras separadas por guion

# %% [markdown]
# *   **Pregunta 12.**
#
# Busca e imprime todas las palabras que terminan en "ing" o "ed".
#
# Indica la cantidad de palabras que encontraste de cada una.

# %%
docs12=[]
for comentario in docs1:
    if re.findall('[\w._%+-]+\w(ing|ed)',comentario):
        new_string= re.findall('[\w._%+-]+\w(ing|ed)',comentario)
       
        if len(new_string)>1:
          for i in range(0,len(new_string)):
             #print(new_string[i], len(new_string[i]))
             docs12.append(new_string[i])
        else:
             docs12.append(new_string)

#print(len(docs3))
docs12
# Out:
# [['ed'],
#  'ed',
#  'ing',
#  'ed',
#  ['ing'],
#  ['ing'],
#  'ed',
#  'ing',
#  'ed',
#  ['ed'],
#  ['ed'],
#  ['ed'],
#  ['ed'],
#  ['ing'],
#  ['ed'],
#  ['ed'],
#  'ing',
#  'ed',
#  ['ing'],
#  'ed',
#  'ed',
#  'ing',
#  ['ed'],
#  ['ing'],
#  ['ed'],
#  'ing',
#  'ing',
#  ['ed'],
#  'ing',
#  'ed',
#  ['ed'],
#  ['ed'],
#  ['ing'],
#  ['ed'],
#  'ed',
#  'ed',
#  'ed',
#  ['ing'],
#  ['ing'],
#  'ed',
#  'ing',
#  'ed',
#  ['ing'],
#  ['ing'],
#  ['ed'],
#  'ed',
#  'ing',
#  'ing',
#  'ing',
#  'ing',
#  'ing',
#  'ing',
#  'ed',
#  'ed',
#  'ing',
#  'ing',
#  'ed',
#  ['ing'],
#  ['ing'],
#  ['ing'],
#  ['ing'],
#  'ing',
#  'ing',
#  ['ing'],
#  ['ed'],
#  'ed',
#  'ed',
#  'ing',
#  'ing',
#  ['ed'],
#  ['ing'],
#  'ed',
#  'ing',
#  'ing',
#  'ed',
#  'ing',
#  'ed',
#  'ed',
#  'ing',
#  ['ing'],
#  'ing',
#  'ing',
#  ['ing'],
#  ['ed'],
#  ['ing'],
#  ['ing'],
#  ['ed'],
#  ['ed'],
#  ['ed'],
#  'ing',
#  'ing',
#  'ing',
#  'ed',
#  'ing',
#  ['ed'],
#  'ed',
# ...

# %%
print("Son", len(docs12), "las palabras separadas por guion")
# Out:
# Son 641 las palabras separadas por guion

# %% [markdown]
# #**Parte 3. Proceso de limpieza.**

# %% [markdown]
# *   **Pregunta 13.**
#
# Ahora realiza un proceso de limpieza del corpus que incluya los siguientes procesos:
#
# *   Solo se deben considerar caracteres alfabéticos. Es decir, se eliminan todos los signos de puntuación y caracteres especiales.
# *   Todos los caracteres alfabéticos se transforman a minúsculas.
# *   Se deben eliminar todos los espacios en blanco adicionales que se puedan encontrar en cada comentario.
#
# Al finalizar dicho proceso de limpieza, imprime el resultado de los primeros 10 comentarios resultantes.

# %%
docs13=[]
for comentario in docs1:
    if re.sub('[^-9A-Za-z ]',"",comentario):
        new_string=  re.sub('[^-9A-Za-z ]',"",comentario)
        docs13.append(new_string)

#docs13
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-3ff85fe14b48> in <cell line: 2>()
#       1 docs13=[]
# ----> 2 for comentario in docs1:
#       3     if re.sub('[^-9A-Za-z ]',"",comentario):
#       4         new_string=  re.sub('[^-9A-Za-z ]',"",comentario)
#       5         docs13.append(new_string)
#
# NameError: name 'docs1' is not defined

# %%
#for comentario in docs13:
#    if re.sub('[A-Z]','[a-z]',comentario):
#        new_string=  re.sub('[A-Z]','[a-z]',comentario)
#        docs13.append(new_string)

# %%
for comentario in docs13:
  new_string=comentario.lower()
  docs13.append(new_string)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-92e26e51506a> in <cell line: 1>()
# ----> 1 for comentario in docs13:
#       2   new_string=comentario.lower()
#       3   docs13.append(new_string)
#
# NameError: name 'docs13' is not defined

# %%
for comentario in docs1:
    if re.sub("  "," ",comentario):
        new_string=  re.sub("  "," ",comentario)
        docs13.append(new_string)
#print(len(docs3))
#docs13

# %%
docs13[0:10]
# Out:
# ['Wow Loved this place',
#  'Crust is not good',
#  'Not tasty and the texture was just nasty',
#  'Stopped by during the late May bank holiday off Rick Steve recommendation and loved it',
#  'The selection on the menu was great and so were the prices',
#  'Now I am getting angry and I want my damn pho',
#  'Honeslty it didnt taste THAT fresh',
#  'The potatoes were like rubber and you could tell they had been made up ahead of time being kept under a warmer',
#  'The fries were great too',
#  'A great touch']

# %% [markdown]
# *   **Pregunta 14.**
#
# Con el resultado de la limpieza obtenido en la pregunta anterior, realiza ahora un proceso de tokenización por palabras del corpus.
#
# Es decir, al final de este proceso de tokenización, debes tener como resultado una lista de listas, donde cada comentario estará tokenizado por palabras.
#
# Al terminar calcula el total de tokens obtenido en todo el corpus.

# %%
docs14=[]
for comentario in docs13:
    if re.findall('\S+',comentario):
       new_string= re.findall('\S+',comentario)
       print(new_string)
       docs14.append(new_string)
     
print(len(docs14))
# Out:
# ['Wow', 'Loved', 'this', 'place']
# ['Crust', 'is', 'not', 'good']
# ['Not', 'tasty', 'and', 'the', 'texture', 'was', 'just', 'nasty']
# ['Stopped', 'by', 'during', 'the', 'late', 'May', 'bank', 'holiday', 'off', 'Rick', 'Steve', 'recommendation', 'and', 'loved', 'it']
# ['The', 'selection', 'on', 'the', 'menu', 'was', 'great', 'and', 'so', 'were', 'the', 'prices']
# ['Now', 'I', 'am', 'getting', 'angry', 'and', 'I', 'want', 'my', 'damn', 'pho']
# ['Honeslty', 'it', 'didnt', 'taste', 'THAT', 'fresh']
# ['The', 'potatoes', 'were', 'like', 'rubber', 'and', 'you', 'could', 'tell', 'they', 'had', 'been', 'made', 'up', 'ahead', 'of', 'time', 'being', 'kept', 'under', 'a', 'warmer']
# ['The', 'fries', 'were', 'great', 'too']
# ['A', 'great', 'touch']
# ['Service', 'was', 'very', 'prompt']
# ['Would', 'not', 'go', 'back']
# ['The', 'cashier', 'had', 'no', 'care', 'what', 'so', 'ever', 'on', 'what', 'I', 'had', 'to', 'say', 'it', 'still', 'ended', 'up', 'being', 'wayyy', 'overpriced']
# ...

# %%
docs14_1=[]
for comentario in docs13:
    if re.findall('\S+',comentario):
        new_string= re.findall('\S+',comentario)
       
        if len(new_string)>1:
          for i in range(0,len(new_string)):
             docs14_1.append(new_string[i])
        else:
             docs14_1.append(new_string)

len(docs14_1)
docs14_1
# Out:
# ['Wow',
#  'Loved',
#  'this',
#  'place',
#  'Crust',
#  'is',
#  'not',
#  'good',
#  'Not',
#  'tasty',
#  'and',
#  'the',
#  'texture',
#  'was',
#  'just',
#  'nasty',
#  'Stopped',
#  'by',
#  'during',
#  'the',
#  'late',
#  'May',
#  'bank',
#  'holiday',
#  'off',
#  'Rick',
#  'Steve',
#  'recommendation',
#  'and',
#  'loved',
#  'it',
#  'The',
#  'selection',
#  'on',
#  'the',
#  'menu',
#  'was',
#  'great',
#  'and',
#  'so',
#  'were',
#  'the',
#  'prices',
#  'Now',
#  'I',
#  'am',
#  'getting',
#  'angry',
#  'and',
#  'I',
#  'want',
#  'my',
#  'damn',
#  'pho',
#  'Honeslty',
#  'it',
#  'didnt',
#  'taste',
#  'THAT',
#  'fresh',
#  'The',
#  'potatoes',
#  'were',
#  'like',
#  'rubber',
#  'and',
#  'you',
#  'could',
#  'tell',
#  'they',
#  'had',
#  'been',
#  'made',
#  'up',
#  'ahead',
#  'of',
#  'time',
#  'being',
#  'kept',
#  'under',
#  'a',
#  'warmer',
#  'The',
#  'fries',
#  'were',
#  'great',
#  'too',
#  'A',
#  'great',
#  'touch',
# ...

# %% [markdown]
# *   **Pregunta 15.**
#
# Finalmente, en este ejercicio definiremos nuestro conjunto de palabras "stopwords", las cuales deberás eliminar de todo el corpus.
#
# Recuerda que ejemplos de stopwords son artículos, adverbios, conectivos, etcétera, que tienen frecuencias de aparición muy altas en cualquier documento, pero que no brindan mucho significado en cuanto al significado de un enunciado.
#
# Con base a la lista de stopwords que se te proporciona, realiza un proceso de limpieza eliminando todas estas palabras del corpus obtenido en el ejercicio anterior.
#
# Obtener cuántos tokens/palabras quedan finalmente en todo el corpus.
#
# Obtener cuántos de estos tokens/palabras son diferentes, es decir, cuántos tokens únicos tendrá lo que llamaremos más adelante nuestro vocabulario.

# %%
# Considera la siguiente lista como tu conjunto de stopwords:
mis_stopwords = ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', 'your', 'yours', 'he', 'him', 'his', 'himself', 'she', 'her', 'hers', 'herself', 'it', 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'should', 'now', 'll']

# %%
len(mis_stopwords)
# Out:
# 121

# %%
docs15 = [w for w in docs14_1 if not w in mis_stopwords] 
  
docs15 = [] 
  
for w in docs14_1: 
    if w not in mis_stopwords: 
        docs15.append(w) 
  

print(docs15)
# Out:
# ['Wow', 'Loved', 'place', 'Crust', 'not', 'good', 'Not', 'tasty', 'texture', 'nasty', 'Stopped', 'late', 'May', 'bank', 'holiday', 'off', 'Rick', 'Steve', 'recommendation', 'loved', 'The', 'selection', 'menu', 'great', 'prices', 'Now', 'I', 'getting', 'angry', 'I', 'want', 'damn', 'pho', 'Honeslty', 'didnt', 'taste', 'THAT', 'fresh', 'The', 'potatoes', 'like', 'rubber', 'could', 'tell', 'made', 'ahead', 'time', 'kept', 'warmer', 'The', 'fries', 'great', 'A', 'great', 'touch', 'Service', 'prompt', 'Would', 'not', 'go', 'back', 'The', 'cashier', 'no', 'care', 'ever', 'I', 'say', 'still', 'ended', 'wayyy', 'overpriced', 'I', 'tried', 'Cape', 'Cod', 'ravoli', 'chickenwith', 'cranberrymmmm', 'I', 'disgusted', 'I', 'pretty', 'sure', 'human', 'hair', 'I', 'shocked', 'no', 'signs', 'indicate', 'cash', 'Highly', 'recommended', 'Waitress', 'little', 'slow', 'service', 'This', 'place', 'not', 'worth', 'time', 'let', 'alone', 'Vegas', 'not', 'like', 'The', 'Burrittos', 'Blah', 'The', 'food', 'am
# ...

# %%
vocabulario = []
for palabra in docs15:
  if palabra not in vocabulario:
    vocabulario.append(palabra)

print(vocabulario)
# Out:
# ['Wow', 'Loved', 'place', 'Crust', 'not', 'good', 'Not', 'tasty', 'texture', 'nasty', 'Stopped', 'late', 'May', 'bank', 'holiday', 'off', 'Rick', 'Steve', 'recommendation', 'loved', 'The', 'selection', 'menu', 'great', 'prices', 'Now', 'I', 'getting', 'angry', 'want', 'damn', 'pho', 'Honeslty', 'didnt', 'taste', 'THAT', 'fresh', 'potatoes', 'like', 'rubber', 'could', 'tell', 'made', 'ahead', 'time', 'kept', 'warmer', 'fries', 'A', 'touch', 'Service', 'prompt', 'Would', 'go', 'back', 'cashier', 'no', 'care', 'ever', 'say', 'still', 'ended', 'wayyy', 'overpriced', 'tried', 'Cape', 'Cod', 'ravoli', 'chickenwith', 'cranberrymmmm', 'disgusted', 'pretty', 'sure', 'human', 'hair', 'shocked', 'signs', 'indicate', 'cash', 'Highly', 'recommended', 'Waitress', 'little', 'slow', 'service', 'This', 'worth', 'let', 'alone', 'Vegas', 'Burrittos', 'Blah', 'food', 'amazing', 'also', 'cute', 'less', 'interior', 'beautiful', 'So', 'performed', 'Thats', 'rightthe', 'red', 'velvet', 'cakeohhh', 'stuff', 
# ...

# %%
len(vocabulario)
# Out:
# 3503

# %% [markdown]
# *   **Comentarios**
#
# Esta actividad fue un acercamiento muy interesante a mi conocmiento de datos no estructurados como los comentarios, pero ademas muy usual conocer textos, me ayudo a reconocer varios conceptos de la estructura de un comentario y ademas me ha permitido conocer la gran utilidad de las estructuras regulares asi como las aplciaciones que tienen dentro de varios proyectos.
# Ordenar y otorgar estructura a los valores permite asociarlo a un elemnto de un conjunto lo que permite aplicar las reglas de los conjuntos y sobre todo asi poder analizar estadisticamente

# %% [markdown]
# << incluye aquí tus comentarios >>

# %% [markdown]
# ##**Fin de la Actividad de la semana 2.**
